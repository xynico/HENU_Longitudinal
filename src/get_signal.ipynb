# %%
import matplotlib.pyplot as plt
import mne
import os
import numpy as np
import pandas as pd
import pickle
from utils import *
file_path_1 = '/data/xiaowei/social_network/HENU/preprocessing/S42_C30_330_F1_40_N50_E2_Raverage/final_eye_close_1002_epoch_concat.pkl'
file_path_2 = '/data/xiaowei/social_network/HENU/preprocessing/S42_C30_330_F1_40_N50_E2_Raverage/final_eye_close_1003_epoch_concat.pkl'
epoch = loadpkl(file_path_1)
fig = epoch.plot_psd(fmin = 1,fmax=40)
fig.savefig('epoch1002.png',dpi=600)
epoch = loadpkl(file_path_2)
fig = epoch.plot_psd(fmin = 1,fmax=40)
fig.savefig('epoch1003.png',dpi=600)
# Out:
#     Using multitaper spectrum estimation with 7 DPSS windows
# <MNELineFigure size 1000x350 with 2 Axes>
#     Using multitaper spectrum estimation with 7 DPSS windows
# <MNELineFigure size 1000x350 with 2 Axes>
